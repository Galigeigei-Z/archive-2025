# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *
from ENTMOOT import *


##########################
# Algorithms & Functions #
##########################



algorithms_test = [
    # LS_QM_v2,
    # opt_SnobFit,
    SRBF,
    PSO_NDCT,
    new_PSO_NDCT,
    DYCORS,
    # opt_SOP,
    COBYLA,
    # COBYQA,
    opt_CUATRO,
    BO,
    ENTMOOT,
    ]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    # 'Levy_f',
    # 'Ackley_f',
    'Rosenbrock_f',
    # 'Antonio_f',
    ]
# multim  = ['Levy_f']
multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    # 5,
    # 7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 1                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    # 50,
    # 100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

home_dir  = 'images/trajectory_plots_1D_&_tables'
SaveData = True

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = True)
# Out:
# =====================  Rosenbrock_f D2
# ==  SRBF
# 100%|██████████| 1/1 [00:00<00:00, 24.27it/s]
# remember to reset the starting values in test function
# ==  PSO_NDCT
# 100%|██████████| 1/1 [00:00<00:00, 58.88it/s]
# remember to reset the starting values in test function
# ==  new_PSO_NDCT
# 100%|██████████| 1/1 [00:00<00:00, 66.80it/s]
# remember to reset the starting values in test function
# ==  DYCORS
# 100%|██████████| 1/1 [00:00<00:00, 23.61it/s]
# remember to reset the starting values in test function
# ==  COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 332.75it/s]
# remember to reset the starting values in test function
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# TR update: iteration 1, objective 1831.700, evaluation 7
# d:\anaconda\envs\chemeng\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:241: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 2, objective 373.737, evaluation 13
# 100%|██████████| 1/1 [00:00<00:00,  5.88it/s]
# ==  BO
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# - No preliminar data supplied, computing data by sobol sequence
# d:\anaconda\envs\chemeng\Lib\site-packages\scipy\optimize\_slsqp_py.py:435: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# 100%|██████████| 17/17 [00:02<00:00,  6.95it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# Set parameter Username
# Set parameter LicenseID to value 2707250
# Academic license - for non-commercial use only - expires 2026-09-11
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]

# %% [markdown]
# ### Benchmark

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

 # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-06-11_18-46-16\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-06-11_18-46-16'

# %% [markdown]
# ### Plot performance tables

# %%
 array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)
# Out:
# ==   SRBF  ==
# ==   PSO_NDCT  ==
# ==   new_PSO_NDCT  ==
# ==   DYCORS  ==
# ==   COBYLA  ==
# ==   opt_CUATRO  ==
# ==   BO  ==
# ==   ENTMOOT  ==
# d:\anaconda\envs\chemeng\Lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\anaconda\envs\chemeng\Lib\site-packages\numpy\core\_methods.py:182: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(

# %%
 ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = SaveData)
# Out:
# The directory 'images/trajectory_plots_1D_&_tables\2025-09-12_15-53-50\tables' does not exist in the root directory. Creating directory.

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=SaveData)
# Out:
# The directory 'images/trajectory_plots_1D_&_tables\2025-09-12_15-53-50\trajectory_plots_1D' does not exist in the root directory.

# %%
ML4CE_uncon_graph_rel(trajectories, algorithms_test, functions_test, N_x_l)
