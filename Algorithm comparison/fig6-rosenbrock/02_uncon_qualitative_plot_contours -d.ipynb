# %% [markdown]
# This is a purely qualitative analysis. This is why this part is detached from the "benchmarking.ipynb". It does its own 2D "benchmarking" but rather to produce the trajectory points that go into the 2D contour plots. The trajectories seen here should qualitatively represent the ones in the benchmarking, however they are not actual runs that went into the performance tables.

# %% [markdown]
# ### Imports

# %%
###########
# Imports #
###########


import copy
# importing algorithms
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *
from ENTMOOT import *

# %% [markdown]
# ### Basic lists and values

# %%
algorithms_test = [

    #  SRBF,
    #  NDCT_standard_PSO,
    #  NDCT_modified_PSO,
    #  DYCORS,
    COBYLA,
    COBYQA,
    opt_CUATRO,
     ENTMOOT,
    ]


functions_test  = [  #!!! Multimodal before Unimodal!!!
     #'Levy_f',
    # 'Ackley_f',
    'Rosenbrock_f',
    # 'Antonio_f',
    ]
multim  = ['Levy_f']

# no. input dimensions
N_x_ = 2

# repetition for random shift
i_rep = 0
reps         = 10
# randShift_l = np.random.uniform(-3,3, (reps,N_x_))
# x_shift_ = randShift_l[i_rep,:].reshape((N_x_,1))



# bounds and other settings
track_x = True
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function
bounds_ = np.array([[-7., 7.], [-7., 7.]]) # x1 bounds, x2 bounds these are taken from the benchmarking routine
# bounds_plot = np.array([[-7, 7], [-7, 7]]) 
bounds_plots_             = np.array([
    [[-7,7],[-7,7]], # Levy
    [[-4,1],[-1,4]], # Ackley
    [[-5,3],[-2,5]], # Rosenbrock
    [[-5,3],[-3,3]]  # Antonio
    ])
samples_number = 10 # for BO

SafeData = True

# %% [markdown]
# Run 2D contours all in one

# %%
# ML4CE_uncon_contour_allin1(functions_test, algorithms_test, N_x_, x_shift_origin, bounds_, bounds_plots_, SafeFig=SafeData)

# %%
ML4CE_uncon_contour_allin1_smooth(functions_test, algorithms_test, N_x_, x_shift_origin, reps, bounds_, bounds_plots_, SafeFig=SafeData)
# Out:
# remember to reset the starting values in test function
# drawing contour
# 100%|██████████| 100/100 [00:00<00:00, 1113.92it/s]
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# COBYLA: Final point (-2.1993, 4.8454), Distance to (1,1) = 5.0023
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# remember to reset the starting values in test function
# COBYQA: Final point (-1.7570, 3.0393), Distance to (1,1) = 3.4293
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 27.757, evaluation 12
# d:\anaconda\envs\chemeng\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:241: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 7, objective 24.007, evaluation 25
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 70.136, evaluation 12
# TR update: iteration 3, objective 33.191, evaluation 15
# TR update: iteration 6, objective 26.363, evaluation 21
# TR update: iteration 7, objective 23.565, evaluation 23
# TR update: iteration 9, objective 19.789, evaluation 27
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 55.379, evaluation 12
# TR update: iteration 3, objective 34.634, evaluation 15
# TR update: iteration 5, objective 26.535, evaluation 19
# TR update: iteration 6, objective 13.401, evaluation 21
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 35.125, evaluation 12
# TR update: iteration 3, objective 21.344, evaluation 15
# TR update: iteration 5, objective 16.036, evaluation 19
# TR update: iteration 7, objective 11.496, evaluation 23
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 30.431, evaluation 12
# TR update: iteration 3, objective 19.762, evaluation 15
# d:\anaconda\envs\chemeng\Lib\site-packages\cvxpy\problems\problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 27.913, evaluation 12
# TR update: iteration 5, objective 24.987, evaluation 21
# TR update: iteration 7, objective 20.960, evaluation 25
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 27.705, evaluation 12
# TR update: iteration 4, objective 26.167, evaluation 20
# TR update: iteration 5, objective 17.739, evaluation 22
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 28.420, evaluation 12
# TR update: iteration 5, objective 22.107, evaluation 20
# TR update: iteration 7, objective 19.954, evaluation 26
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 25.402, evaluation 12
# TR update: iteration 4, objective 13.041, evaluation 17
# TR update: iteration 7, objective 8.053, evaluation 26
# remember to reset the starting values in test function
# TR update: iteration 1, objective 486.482, evaluation 7
# TR update: iteration 2, objective 39.536, evaluation 12
# TR update: iteration 4, objective 21.254, evaluation 19
# remember to reset the starting values in test function
# opt_CUATRO: Final point (-1.8748, 3.4985), Distance to (1,1) = 3.8088
# remember to reset the starting values in test function
# Set parameter Username
# Set parameter LicenseID to value 2707250
# Academic license - for non-commercial use only - expires 2026-09-11
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# remember to reset the starting values in test function
# ENTMOOT: Final point (0.0000, 0.0000), Distance to (1,1) = 1.4142
#
# Algorithm runtime summary:
# COBYLA: 0.00 seconds (for 10 runs)
# COBYQA: 0.45 seconds (for 10 runs)
# opt_CUATRO: 3.05 seconds (for 10 runs)
# ENTMOOT: 31.70 seconds (for 10 runs)
