# %%
{
    "SRBF": {
        "run1": {"distance": 0.7120, "time": 0.32},
        "run2": {"distance": 0.7625, "time": 0.33},
        "run3": {"distance": 0.9284, "time": 0.33},
        "run4": {"distance": 1.2907, "time": 0.32},
        "run5": {"distance": 1.4142, "time": 0.32}
    },
    "NDCT_standard_PSO": {
        "run1": {"distance": 1.6171, "time": 0.11},
        "run2": {"distance": 0.5584, "time": 0.12},
        "run3": {"distance": 1.0111, "time": 0.12},
        "run4": {"distance": 1.8553, "time": 0.12},
        "run5": {"distance": 1.9111, "time": 0.10}
    },
    "NDCT_modified_PSO": {
        "run1": {"distance": 0.7212, "time": 0.20},
        "run2": {"distance": 0.7643, "time": 0.17},
        "run3": {"distance": 1.0464, "time": 0.20},
        "run4": {"distance": 1.4101, "time": 0.19},
        "run5": {"distance": 1.0446, "time": 0.18}
    },
    "DYCORS": {
        "run1": {"distance": 1.1820, "time": 0.58},
        "run2": {"distance": 0.7565, "time": 0.59},
        "run3": {"distance": 0.2782, "time": 0.58},
        "run4": {"distance": 1.4142, "time": 0.54},
        "run5": {"distance": 0.9499, "time": 0.58}
    },
    "COBYLA": {
        "run1": {"distance": 5.0023, "time": 0.01},
        "run2": {"distance": 5.0023, "time": 0.01},
        "run3": {"distance": 5.0023, "time": 0.00},
        "run4": {"distance": 5.0023, "time": 0.00},
        "run5": {"distance": 5.0023, "time": 0.01},
    },
    "COBYQA": {
        "run1": {"distance": 3.4293, "time": 0.46},
        "run2": {"distance": 3.4293, "time": 0.49},
        "run3": {"distance": 3.4293, "time": 0.49},
        "run4": {"distance": 3.4293, "time": 0.42},
        "run5": {"distance": 3.4293, "time": 0.51}
    },
    "opt_CUATRO": {
        "run1": {"distance": 4.1050, "time": 3.81},
        "run2": {"distance": 4.1180, "time": 3.47},
        "run3": {"distance": 4.0382, "time": 3.34},
        "run4": {"distance": 4.1307, "time": 3.90},
        "run5": {"distance": 4.1002, "time": 3.95},
    },
    "ENTMOOT": {
        "run1": {"distance": 1.4142, "time": 31.44},
        "run2": {"distance": 1.4142, "time": 31.53},
        "run3": {"distance": 1.4142, "time": 30.74},
        "run4": {"distance": 1.4142, "time": 31.69},
        "run5": {"distance": 1.4142, "time": 31.12},
    }
}
# Out:
# {'SRBF': {'run1': {'distance': 0.712, 'time': 0.32},
#   'run2': {'distance': 0.7625, 'time': 0.33},
#   'run3': {'distance': 0.9284, 'time': 0.33},
#   'run4': {'distance': 1.2907, 'time': 0.32},
#   'run5': {'distance': 1.4142, 'time': 0.32}},
#  'NDCT_standard_PSO': {'run1': {'distance': 1.6171, 'time': 0.11},
#   'run2': {'distance': 0.5584, 'time': 0.12},
#   'run3': {'distance': 1.0111, 'time': 0.12},
#   'run4': {'distance': 1.8553, 'time': 0.12},
#   'run5': {'distance': 1.9111, 'time': 0.1}},
#  'NDCT_modified_PSO': {'run1': {'distance': 0.7212, 'time': 0.2},
#   'run2': {'distance': 0.7643, 'time': 0.17},
#   'run3': {'distance': 1.0464, 'time': 0.2},
#   'run4': {'distance': 1.4101, 'time': 0.19},
#   'run5': {'distance': 1.0446, 'time': 0.18}},
#  'DYCORS': {'run1': {'distance': 1.182, 'time': 0.58},
#   'run2': {'distance': 0.7565, 'time': 0.59},
#   'run3': {'distance': 0.2782, 'time': 0.58},
#   'run4': {'distance': 1.4142, 'time': 0.54},
# ...

# %%
import numpy as np
import pandas as pd


results = {
    "SRBF": {
        1: {"distance": 0.7120, "time": 0.32},
        2: {"distance": 0.7625, "time": 0.33},
        3: {"distance": 0.9284, "time": 0.33},
        4: {"distance": 1.2907, "time": 0.32},
        5: {"distance": 1.4142, "time": 0.32}
    },
    "PSO": {   # NDCT_standard_PSO
        1: {"distance": 1.6171, "time": 0.11},
        2: {"distance": 0.5584, "time": 0.12},
        3: {"distance": 1.0111, "time": 0.12},
        4: {"distance": 1.8553, "time": 0.12},
        5: {"distance": 1.9111, "time": 0.10}
    },
    "mPSO": {  # NDCT_modified_PSO
        1: {"distance": 0.7212, "time": 0.20},
        2: {"distance": 0.7643, "time": 0.17},
        3: {"distance": 1.0464, "time": 0.20},
        4: {"distance": 1.4101, "time": 0.19},
        5: {"distance": 1.0446, "time": 0.18}
    },
    "DYCORS": {
        1: {"distance": 1.1820, "time": 0.58},
        2: {"distance": 0.7565, "time": 0.59},
        3: {"distance": 0.2782, "time": 0.58},
        4: {"distance": 1.4142, "time": 0.54},
        5: {"distance": 0.9499, "time": 0.58}
    },
    "COBYLA": {
        1: {"distance": 5.0023, "time": 0.01},
        2: {"distance": 5.0023, "time": 0.01},
        3: {"distance": 5.0023, "time": 0.00},
        4: {"distance": 5.0023, "time": 0.00},
        5: {"distance": 5.0023, "time": 0.01},
    },
    "COBYQA": {
        1: {"distance": 3.4293, "time": 0.46},
        2: {"distance": 3.4293, "time": 0.49},
        3: {"distance": 3.4293, "time": 0.49},
        4: {"distance": 3.4293, "time": 0.42},
        5: {"distance": 3.4293, "time": 0.51}
    },
    "CUATRO": {   # opt_CUATRO
        1: {"distance": 4.1050, "time": 3.81},
        2: {"distance": 4.1180, "time": 3.47},
        3: {"distance": 4.0382, "time": 3.34},
        4: {"distance": 4.1307, "time": 3.90},
        5: {"distance": 4.1002, "time": 3.95},
    },
    "ENTMOOT": {
        1: {"distance": 1.4142, "time": 31.44},
        2: {"distance": 1.4142, "time": 31.53},
        3: {"distance": 1.4142, "time": 30.74},
        4: {"distance": 1.4142, "time": 31.69},
        5: {"distance": 1.4142, "time": 31.12},
    }
}


def compute_relative_scores(results: dict, metric: str, eps: float = 1e-12):
    """
    metric: "time" 或 "distance"
      - time 越小越好
      - distance 越小越好
    """
    algs = list(results.keys())
    ks = sorted(next(iter(results.values())).keys())


    Y = np.array([[results[a][k][metric] for a in algs] for k in ks], dtype=float)


    worst = Y.max(axis=1)
    best = Y.min(axis=1)
    denom = worst - best

    R = np.empty_like(Y)
    mask = denom > eps
    if mask.any():
        R[mask, :] = (worst[mask, None] - Y[mask, :]) / (denom[mask, None])
    if (~mask).any():
        R[~mask, :] = 1.0

    R = np.clip(R, 0.0, 1.0)


    r_df = pd.DataFrame(R, index=ks, columns=algs)


    p = r_df.mean(axis=0).reindex(algs)

    return r_df, p

r_time, p_time = compute_relative_scores(results, metric="time")
print("=== Time relative scores ===")
print(r_time.round(3))
print("\nOverall time score (mean):")
print(p_time.round(3))

r_dist, p_dist = compute_relative_scores(results, metric="distance")
print("\n=== Distance relative scores ===")
print(r_dist.round(3))
print("\nOverall distance score (mean):")
print(p_dist.round(3))
# Out:
# === Time relative scores ===
#     SRBF    PSO   mPSO  DYCORS  COBYLA  COBYQA  CUATRO  ENTMOOT
# 1  0.990  0.997  0.994   0.982     1.0   0.986   0.879      0.0
# 2  0.990  0.997  0.995   0.982     1.0   0.985   0.890      0.0
# 3  0.989  0.996  0.993   0.981     1.0   0.984   0.891      0.0
# 4  0.990  0.996  0.994   0.983     1.0   0.987   0.877      0.0
# 5  0.990  0.997  0.995   0.982     1.0   0.984   0.873      0.0
#
# Overall time score (mean):
# SRBF       0.990
# PSO        0.997
# mPSO       0.994
# DYCORS     0.982
# COBYLA     1.000
# COBYQA     0.985
# CUATRO     0.882
# ENTMOOT    0.000
# dtype: float64
#
# === Distance relative scores ===
#     SRBF    PSO   mPSO  DYCORS  COBYLA  COBYQA  CUATRO  ENTMOOT
# 1  1.000  0.789  0.998   0.890     0.0   0.367   0.209    0.836
# 2  0.954  1.000  0.954   0.955     0.0   0.354   0.199    0.807
# 3  0.862  0.845  0.837   1.000     0.0   0.333   0.204    0.760
# 4  1.000  0.848  0.968   0.967     0.0   0.424   0.235    0.967
# ...
